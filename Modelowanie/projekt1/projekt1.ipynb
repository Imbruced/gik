# %%
import geopandas as gpd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataframe = gpd.read_file('dane_wejsciowe\L1_2_BDOT10k__OT_ADJA_A.shp')
dataframe.plot()

# %%
dataframe.head(1).plot()

# %%
rzeki = gpd.read_file('dane_wejsciowe\L1_2_BDOT10k__OT_SWRS_L.shp')

# %%
rzeki.plot()

# %%
rzeki['to_color'] = rzeki['x_katDoklG'].apply(lambda x: 0 if x == 'Prz' else 1)

# %%
rzeki.plot(column='to_color', cmap='rainbow')
